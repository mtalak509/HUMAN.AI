# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

RND_SRC = Path(r"C:/dev/HUMAN.AI/rnd/src")
if str(RND_SRC) not in sys.path:
    sys.path.insert(0, str(RND_SRC))

import pdf_parser
from openrouter_client import OpenRouterClient
from json_schema import Resume

client = OpenRouterClient()
print("model:", client.model)
# Out:
# model: qwen/qwen3.6-plus

# %%
PDF_PATH = r"C:/dev/HUMAN.AI/rnd/data/resume/Suhanova.pdf"
raw_resume_text = pdf_parser.pdf_to_text(PDF_PATH)
print(raw_resume_text[:500])
# Out:
# 2026-05-15 15:20:36.099 | INFO     | pdf_parser:pdf_to_text:15 - pdf_to_text: reading C:\dev\HUMAN.AI\rnd\data\resume\Suhanova.pdf
# 2026-05-15 15:20:36.145 | INFO     | pdf_parser:pdf_to_text:27 - pdf_to_text: Suhanova.pdf — pages=4, chars=9327, empty_pages=none
# --- PAGE 1 ---
# Суханова Валерия Андреевна
# Женщина
# +7 (916) 5770925 — предпочитаемый способ связи
# lerateryaeva@mail.ru
# Проживает: Сербия
# Гражданство: Россия, есть разрешение на работу: Россия
# Готова работать удалённо: Москва, готова к командировкам
# Желаемая должность и зарплата
# Travel Manager
# Специализации:
# —  Менеджер по туризму
# Тип занятости: полная занятость
# Формат работы: удалённо
# Желательное время в пути до работы: не имеет значения
# Опыт работы — 8 лет 4 месяца
# Август 2024 —
# настоящее время

# %%
parsed, raw = client.extract_resume(resume_text=raw_resume_text)

results_dir = Path(r"C:/dev/HUMAN.AI/rnd/data/results")
results_dir.mkdir(parents=True, exist_ok=True)
parsed_out = results_dir / f"{Path(PDF_PATH).stem}.parsed.json"
parsed_out.write_text(
    parsed.model_dump_json(indent=2, exclude_none=False),
    encoding="utf-8",
)

print(f"Saved parsed JSON: {parsed_out}")

# %%
structured, raw = client.extract_resume_structured(resume_text=raw_resume_text)

results_dir = Path(r"C:/dev/HUMAN.AI/rnd/data/results")
results_dir.mkdir(parents=True, exist_ok=True)
structured_out = results_dir / f"{Path(PDF_PATH).stem}.structured.json"
structured_out.write_text(
    structured.model_dump_json(indent=2, exclude_none=False),
    encoding="utf-8",
)

print(f"Saved structured JSON: {structured_out}")
# Out:
# 2026-05-15 15:20:43.776 | INFO     | openrouter_client:extract_resume_structured:144 - extract_resume_structured: resume_chars=9327, strict=False
# 2026-05-15 15:20:43.781 | INFO     | openrouter_client:_call_structured:101 - LLM call: model=qwen/qwen3.6-plus, mode=json_schema, strict=False, prompt_chars=13784
# 2026-05-15 15:23:06.173 | INFO     | openrouter_client:_call_structured:128 - LLM response: response_chars=5262, usage={'completion_tokens': 7678, 'prompt_tokens': 4017, 'total_tokens': 11695, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 6039, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 0.016277625, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 0.016277625, 'upstream_inference_prompt_cost': 0.001305525, 'upstream_inference_completions_cost': 0.0149721}}
# 2026-05-15 15:23:06.175 | INFO     | openrouter_client:extract_resume_structured:152 - extract_resume_structured: OK — name='Суханова Валерия Андреевна', exp=5, edu=2, skills=16
# Saved structured JSON: C:\dev\HUMAN.AI\rnd\data\results\Suhanova.structured.json
